# %% [markdown]
# <a href="https://colab.research.google.com/github/gbrlaacst21/NRC-Spanish/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install mysql.connector

# %%
# !pip3 install mysql-connector-python

# %%
import mysql.connector

# %%
#DATOS PARA LA CONEXION CON SQL
args_sql = { 'host': 'ec2-3-136-67-45.us-east-2.compute.amazonaws.com', 
            'database': 'viasc', 
            'user': 'lytica', 
            'password': 'Jg8mfPpkHcF7aexH'
           }

# %%
#CONEXION
connection = mysql.connector.connect(**args_sql) 
cursor = connection.cursor()

# %%
cursor.execute('''SELECT * FROM account_emailaddress''')
ejemplo = cursor.fetchall()

# %%
ejemplo
# Out:
# [(1, 'gibran.aguilar@lytica.ai', 1, 1, 2),
#  (2, 'mariohdpz@gmail.com', 1, 1, 3),
#  (3, 'mariohdpz123@gmail.com', 1, 1, 4)]

# %%
cursor.execute('''SHOW tables''')
tables = cursor.fetchall()
tables = [str(i[0].decode('utf-8')) for i in tables]
print(tables)
# Out:
# ['account_emailaddress', 'account_emailconfirmation', 'address', 'adjacency', 'appraisal', 'appraisal_address', 'appraisal_factor', 'appraisal_stages', 'appraiser', 'auth_group', 'auth_group_permissions', 'auth_permission', 'authtoken_token', 'cadastre', 'cat_acometida_gas_nat', 'cat_administracion', 'cat_alumbrado_publico', 'cat_banquetas', 'cat_calidad_proyeco', 'cat_calidad_proyecto', 'cat_clase_construccion', 'cat_clase_general_inmueble', 'cat_clasificacion_zona', 'cat_configuracion_inmueble', 'cat_densidad_habitacional', 'cat_densidad_habitacional_viv', 'cat_densidad_poblacion', 'cat_derecho_transito', 'cat_estado_conservacion', 'cat_fuente_legal', 'cat_guarniciones', 'cat_instalaciones', 'cat_margen', 'cat_nivel', 'cat_nivel_equipamiento', 'cat_nivel_infraestructura', 'cat_nivel_socioeconomico', 'cat_pollution', 'cat_rango_nivel', 'cat_red_distribucion', 'cat_red_recoleccion', 'cat_red_telefono', 'cat_ref_proximidad', 'cat_regimen', 'cat_reporte_densidad', 'cat_riesgo_comercial
# ...

# %%
#número de registros por tabal
for i in tables:
    table = i
    print(table)
    cursor.execute(f'''SELECT count(*)
                    FROM {table}''')
    rows = cursor.fetchone()
    print(rows)
# Out:
# account_emailaddress
# (3,)
# account_emailconfirmation
# (0,)
# address
# (3,)
# adjacency
# (1,)
# appraisal
# (3,)
# appraisal_address
# (3,)
# appraisal_factor
# (0,)
# appraisal_stages
# (137,)
# appraiser
# (65,)
# auth_group
# (0,)
# auth_group_permissions
# (0,)
# auth_permission
# (440,)
# authtoken_token
# (0,)
# cadastre
# (1,)
# cat_acometida_gas_nat
# (4,)
# cat_administracion
# (4,)
# cat_alumbrado_publico
# (4,)
# cat_banquetas
# (6,)
# cat_calidad_proyeco
# (4,)
# cat_calidad_proyecto
# (4,)
# cat_clase_construccion
# (10,)
# cat_clase_general_inmueble
# (7,)
# cat_clasificacion_zona
# (18,)
# cat_configuracion_inmueble
# (3,)
# cat_densidad_habitacional
# (6,)
# cat_densidad_habitacional_viv
# (8,)
# cat_densidad_poblacion
# (8,)
# cat_derecho_transito
# (2,)
# cat_estado_conservacion
# (8,)
# cat_fuente_legal
# (5,)
# cat_guarniciones
# (4,)
# cat_instalaciones
# (51,)
# cat_margen
# (2,)
# cat_nivel
# (34,)
# cat_nivel_equipamiento
# (4,)
# ...

# %%
#numero de columnas por cada tabla
for i in tables:
    table = i
    print(table)
    cursor.execute(f'''SELECT count(*)
                    FROM INFORMATION_SCHEMA.COLUMNS
                    WHERE TABLE_NAME = '{table}'
                    ORDER BY ORDINAL_POSITION''')
    number_columns = cursor.fetchone()
    print(number_columns)
# Out:
# account_emailaddress
# (5,)
# account_emailconfirmation
# (5,)
# address
# (12,)
# adjacency
# (7,)
# appraisal
# (16,)
# appraisal_address
# (16,)
# appraisal_factor
# (13,)
# appraisal_stages
# (6,)
# appraiser
# (5,)
# auth_group
# (2,)
# auth_group_permissions
# (3,)
# auth_permission
# (4,)
# authtoken_token
# (3,)
# cadastre
# (9,)
# cat_acometida_gas_nat
# (5,)
# cat_administracion
# (5,)
# cat_alumbrado_publico
# (5,)
# cat_banquetas
# (5,)
# cat_calidad_proyeco
# (5,)
# cat_calidad_proyecto
# (5,)
# cat_clase_construccion
# (5,)
# cat_clase_general_inmueble
# (5,)
# cat_clasificacion_zona
# (5,)
# cat_configuracion_inmueble
# (5,)
# cat_densidad_habitacional
# (5,)
# cat_densidad_habitacional_viv
# (5,)
# cat_densidad_poblacion
# (5,)
# cat_derecho_transito
# (5,)
# cat_estado_conservacion
# (5,)
# cat_fuente_legal
# (5,)
# cat_guarniciones
# (5,)
# cat_instalaciones
# (5,)
# cat_margen
# (5,)
# cat_nivel
# (5,)
# cat_nivel_equipamiento
# (5,)
# cat_nivel_infraestructura
# ...
